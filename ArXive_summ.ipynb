# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasnulsanna/Generative-AI/blob/main/ArXive_summ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install arxiv
# !pip install transformers
# !pip install datasets
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 2.3 MB/s eta 0:00:00
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=b216d345dae57832885c738a82d74ac3e24c177952e6b8060928161ea40ebf25
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# ...

# %%
import arxiv
import pandas as pd

query = "ai or Artificial Intelligence or Machine Learning"
search = arxiv.Search(query=query,max_results=10,sort_by=arxiv.SortCriterion.SubmittedDate)

paper =[]
for result in search.results():
  paper.append({
      'published':result.published,
      'title':result.title,
      'summary':result.summary,
      'category':result.categories
      })

df=pd.DataFrame(paper)
pd.set_option('display.max_colwidth', None)
df.head(10)
# Out:
# <ipython-input-11-4c8704db2df9>:8: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   for result in search.results():
#                   published  \
# 0 2024-11-12 18:59:59+00:00
# 1 2024-11-12 18:59:35+00:00
# 2 2024-11-12 18:59:32+00:00
# 3 2024-11-12 18:59:31+00:00
# 4 2024-11-12 18:57:59+00:00
# 5 2024-11-12 18:56:58+00:00
# 6 2024-11-12 18:55:01+00:00
# 7 2024-11-12 18:54:55+00:00
# 8 2024-11-12 18:52:20+00:00
# 9 2024-11-12 18:50:35+00:00
#
#                                                                                                                  title  \
# 0                                                           Material Transforms from Disentangled NeRF Representations
# 1                                                          Scaling Properties of Diffusion Models for Perceptual Tasks
# 2                                         GaussianAnything: Interactive Point Cloud Latent Diffusion for 3D Generation
# ...

# %%
abstract = df['summary'][0]

# %%
from transformers import pipeline
summerize = pipeline("summarization",model="facebook/bart-large-cnn")

summary=summerize(abstract)
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
summary[0]['summary_text']
# Out:
# 'A novel method for transferring materialtransformations across different scenes. Building on disentangled NeuralRadiance Field representations, our approach learns to map BidirectionalReflectance Distribution Functions (BRDF) from pairs of scenes observed in dry and wet. The learned transformations can then be applied to unseen scenes.'
